# %%
import pandas as pd
df=pd.read_csv("testdata.csv")
df.head()
# Out:
#     x   y
# 0  15  49
# 1  23  63
# 2  18  58
# 3  23  60
# 4  24  58

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)                                                                                               
print(y_test.shape)
# Out:
# (13, 1)
# (2, 1)
# (13,)
# (2,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
print(y_pred)
# Out:
# [47.45652174 62.60810811 53.13836663 62.60810811 64.5020564  60.71415981
#  60.71415981 55.03231492 55.03231492 49.35047004 64.5020564  39.88072855
#  64.5020564  49.35047004 62.60810811]

# %%
df1=pd.DataFrame({"Actual":y,"Predicted":y_pred})
df1
# Out:
#     Actual  Predicted
# 0       49  47.456522
# 1       63  62.608108
# 2       58  53.138367
# 3       60  62.608108
# 4       58  64.502056
# 5       61  60.714160
# 6       60  60.714160
# 7       63  55.032315
# 8       60  55.032315
# 9       52  49.350470
# 10      62  64.502056
# 11      30  39.880729
# 12      59  64.502056
# 13      49  49.350470
# 14      68  62.608108

# %%
print("Coefficient",lr.coef_)
print("Intercept",lr.intercept_)
# Out:
# Coefficient [1.8939483]
# Intercept 19.047297297297284

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,y_pred))
print("MSE:",metrics.mean_squared_error(y,y_pred))
print("R2 Score:",metrics.r2_score(y,y_pred))
# Out:
# MAE: 3.7412847630238946
# MSE: 22.292068155111636
# R2 Score: 0.7088287858527738

# %%
import pandas as pd
df=pd.read_csv("Study.csv")
df
# Out:
#    Hours Studied(X)  Exam Score(y)
# 0               NaN            NaN
# 1               1.0           50.0
# 2               2.0           55.0
# 3               3.0           65.0
# 4               4.0           70.0
# 5               5.0           75.0
# 6               6.0           80.0
# 7               7.0           85.0

# %%
a=df.dropna()
a
# Out:
#    Hours Studied(X)  Exam Score(y)
# 1               1.0           50.0
# 2               2.0           55.0
# 3               3.0           65.0
# 4               4.0           70.0
# 5               5.0           75.0
# 6               6.0           80.0
# 7               7.0           85.0

# %%
a.reset_index(drop=True)
# Out:
#    Hours Studied(X)  Exam Score(y)
# 0               1.0           50.0
# 1               2.0           55.0
# 2               3.0           65.0
# 3               4.0           70.0
# 4               5.0           75.0
# 5               6.0           80.0
# 6               7.0           85.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)                                                                                               
print(y_test.shape)
# Out:
# (13, 1)
# (2, 1)
# (13,)
# (2,)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue',label='Actual Scores')
plt.plot(x,y_pred,color='red',label='Predicted Line')
plt.xlabel("Hours studied")
plt.ylabel("Exam Score")
plt.title("Exam Score vs Hours Studided")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
error=[]
for i in range(1,43):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i) 
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    error.append(metrics.mean_absolute_error(y_test,y_pred))
print(error)
# Out:
# [5.422475106685635, 10.933393070489842, 8.325590872045638, 4.241935483870968, 0.4198834668608953, 12.130336351875808, 3.0202984038861906, 8.741160220994473, 4.514369933677234, 5.422475106685635, 3.9011379800853483, 5.551344743276303, 7.0847457627118615, 1.4666788055353237, 5.940064794816411, 10.436977299880528, 3.386221701795474, 8.74116022099448, 6.418938835666911, 12.381548974943051, 3.547159504734161, 7.77169274537696, 10.933393070489842, 3.4314912944738865, 3.3847671665351307, 3.9051215917465036, 2.084784254352769, 5.940064794816411, 7.636330140014731, 2.451612903225808, 6.1114591009579975, 8.325590872045652, 0.9664401019541202, 4.241935483870968, 4.708554125662381, 10.436977299880532, 3.0775248933143615, 4.052611657834984, 5.645413870246077, 4.241935483870964, 7.529411764705877, 9.477684346701174]

# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.isna().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.shape
# Out:
# (200, 2)

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,1]

# %%
print(x.shape)
print(y.shape)
# Out:
# (200, 1)
# (200,)

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
x=df[['cgpa']]
y=df[['package']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)                                                                                               
print(y_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [2.9383335  4.36894346 3.18258398 1.89736121 3.49662031 3.35123312
#  2.76968435 2.94996447 3.07208971 3.94441286 3.57222165 2.94996447
#  2.75805338 2.64755911 3.67108494 3.2174769  3.97930579 2.90925606
#  2.19395108 3.31052471 4.29915761 2.8918096  1.87409926 2.30444534
#  3.62456104 2.12998071 3.9269664  2.36841571 1.5716939  2.06601035
#  2.31026083 3.6885314  3.5024358  3.03719679 2.57195777 2.39167766
#  3.170953   3.82228762 3.15932203 2.94414898]

# %%
diff=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
diff
# Out:
#      Actual  Predicted
# 58     3.09   2.938333
# 40     4.02   4.368943
# 34     3.42   3.182584
# 102    1.37   1.897361
# 184    3.14   3.496620
# 198    3.96   3.351233
# 95     2.79   2.769684
# 4      3.57   2.949964
# 29     3.49   3.072090
# 168    3.52   3.944413
# 171    3.76   3.572222
# 18     2.98   2.949964
# 11     2.60   2.758053
# 89     2.72   2.647559
# 110    3.76   3.671085
# 118    2.88   3.217477
# 159    4.08   3.979306
# 35     2.87   2.909256
# 136    2.10   2.193951
# 59     3.31   3.310525
# 51     3.79   4.299158
# 16     2.35   2.891810
# 44     1.86   1.874099
# 94     2.42   2.304445
# 31     3.89   3.624561
# 162    2.55   2.129981
# 38     4.36   3.926966
# 28     2.24   2.368416
# 193    1.94   1.571694
# 27     2.16   2.066010
# 47     3.26   2.310261
# 165    4.08   3.688531
# 194    3.67   3.502436
# 177    3.64   3.037197
# 176    3.23   2.571958
# 97     2.84   2.391678
# 174    2.99   3.170953
# 73     4.03   3.822288
# 69     2.94   3.159322
# 172    2.51   2.944149

# %%
print("Coefficient:",lr.coef_)
print("Intercept",lr.intercept_)
# Out:
# Coefficient: [0.58154877]
# Intercept -1.0859839580358033

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_squared_error(y_test,y_pred))
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 0.29931188593316804
# MSE: 0.1370062519255722
# R2 Score: 0.7283345498058083

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
error=[]
for i in range(1,43):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i) 
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    error.append(metrics.mean_absolute_error(y_test,y_pred))
print(error)
# Out:
# [0.2407378157739672, 0.26530089639951643, 0.2774773465328067, 0.2773804762131485, 0.22217164056903177, 0.24610140446676682, 0.2744809634282523, 0.1900674770114435, 0.30312847352135297, 0.3053799731640427, 0.2047747447750127, 0.26834795229806846, 0.22002771263570436, 0.2880971145604986, 0.3190224033237626, 0.2867348370439097, 0.22382275376315955, 0.3240556353991659, 0.19262495489942194, 0.27699532261624016, 0.19276836878458545, 0.2748194995975493, 0.2934977127421374, 0.2744272389489727, 0.24952124295208983, 0.2370463786551631, 0.35347668516774783, 0.30593404210615727, 0.2897122460927034, 0.1970162351065391, 0.2496955129042056, 0.21447579972261285, 0.3100574581655361, 0.2821441386669218, 0.3006793489645595, 0.3355512507149799, 0.2906267122248951, 0.24235831115194717, 0.1917412935775777, 0.3181235382558296, 0.29025518692791613, 0.26202273905512097]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_test,y_pred,color='red',label='Predicted Line')
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.title("CGPA vs Package")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(x_test,y_pred,color='red',label='Predicted Line')
plt.scatter(x_test,y_test)
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
sns.regplot(data=df,x='cgpa',y='package')
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
ypred=lr.predict([[9.5]])
print(ypred)
# Out:
# [4.41606532]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
df=pd.read_csv("car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['Car_Name'].nunique()
# Out:
# 98

# %%
a=df.drop(columns=['Car_Name'])
a
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
a['Age']=2026-a['Year']
a['Age']
# Out:
# 0      12
# 1      13
# 2       9
# 3      15
# 4      12
#        ..
# 296    10
# 297    11
# 298    17
# 299     9
# 300    10
# Name: Age, Length: 301, dtype: int64

# %%
a
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   12
# 1         Manual      0   13
# 2         Manual      0    9
# 3         Manual      0   15
# 4         Manual      0   12
# ..           ...    ...  ...
# 296       Manual      0   10
# 297       Manual      0   11
# 298       Manual      0   17
# 299       Manual      0    9
# 300       Manual      0   10
#
# [301 rows x 9 columns]

# %%
a.drop(columns=['Year'],inplace=True)

# %%
a.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0   12
# 1       Manual      0   13
# 2       Manual      0    9
# 3       Manual      0   15
# 4       Manual      0   12

# %%
a.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'Age',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
a=pd.get_dummies(data=a,drop_first=True)
a
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   12             False
# 1             4.75           9.54       43000      0   13              True
# 2             7.25           9.85        6900      0    9             False
# 3             2.85           4.15        5200      0   15             False
# 4             4.60           6.87       42450      0   12              True
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0   10              True
# 297           4.00           5.90       60000      0   11             False
# 298           3.35          11.00       87934      0   17             False
# 299          11.50          12.50        9000      0    9              True
# 300           5.30           5.90        5464      0   10             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                True                   False                 True
# 1               False                   False                 True
# 2                True                   False                 True
# 3                True                   False                 True
# 4               False                   False                 True
# ..                ...                     ...                  ...
# 296             False                   False                 True
# 297              True                   False                 True
# 298              True                   False                 True
# 299             False                   False                 True
# 300              True                   False                 True
#
# [301 rows x 9 columns]

# %%
y=a['Selling_Price']
x=a.drop('Selling_Price',axis=1)

# %%
x.shape
# Out:
# (301, 8)

# %%
y.shape
# Out:
# (301,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)                                                                                               
print(y_test.shape)
# Out:
# (240, 8)
# (61, 8)
# (240,)
# (61,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [ 7.86273200e+00  2.96828691e+00 -5.90305107e-01  4.21335952e+00
#   4.83175534e-01  5.82053813e+00  1.95679784e+00  2.55809661e+00
#   7.70870833e+00  9.78692192e-01  8.13484343e+00  3.51207180e+00
#   4.90669281e+00  4.63905587e+00 -2.15886643e+00  3.13874624e+00
#   7.98256903e+00  6.75937638e+00  6.90426580e+00  8.01440587e+00
#   4.31168610e+00  4.00336757e+00  1.13040883e+01  8.07939189e+00
#   9.54399823e+00  3.52133877e+00  3.80609808e+00  1.06074722e+00
#  -6.01732475e-01 -6.19712043e-01  1.32818516e-03 -1.28500691e+00
#   4.28533553e+00  2.06769487e+01  1.87563232e+01  4.27292100e+00
#   3.48602852e+00  1.66739677e+00 -4.38707073e-02  5.78536030e+00
#   8.03940428e+00  9.88367483e+00  4.09684249e-01  6.07997517e+00
#   5.88038915e+00  4.32745252e+00  7.37534505e+00  5.86171335e+00
#   8.21129880e+00  1.65455816e+00  3.83033706e+00  1.75047060e+00
#   2.51406796e+00  4.20404709e+00  1.48991546e+00 -3.44185843e+00
#   2.04806215e+01  6.62503544e-01  5.40027412e+00  5.65856241e+00
#   6.47876234e-01]

# %%
diff=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
diff
# Out:
#      Actual  Predicted
# 285    7.40   7.862732
# 248    4.00   2.968287
# 150    0.50  -0.590305
# 217    3.15   4.213360
# 107    1.25   0.483176
# ..      ...        ...
# 62    18.75  20.480622
# 154    0.50   0.662504
# 218    6.45   5.400274
# 286    5.65   5.658562
# 186    0.25   0.647876
#
# [61 rows x 2 columns]

# %%
print("Coefficient:",lr.coef_)
print("Intercept",lr.intercept_)
# Out:
# Coefficient: [ 4.37233976e-01 -5.30613944e-06  3.45912849e-01 -4.13270098e-01
#   2.23050770e+00  4.58549217e-01 -1.20927814e+00 -1.87014327e+00]
# Intercept 7.900300130264206

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_squared_error(y_test,y_pred))
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 1.0998575552990955
# MSE: 2.9823848618597513
# R2 Score: 0.8625260513315252

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
error=[]
for i in range(1,43):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i) 
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    error.append(metrics.mean_absolute_error(y_test,y_pred))
print(error)
# Out:
# [1.1782028069641932, 1.0725913724011022, 1.3558024828257547, 1.0570171256619871, 1.2143693528631425, 1.1809862444038852, 1.4135442416098944, 1.669867333898268, 1.4581558749457224, 1.5433818924674017, 0.9056358334256293, 1.3494555898122866, 1.458052126257879, 1.5761176265761225, 1.3530752593611177, 1.4414144633082342, 1.6264929828793724, 1.0078411882752312, 0.8260359568377477, 0.9555010468143124, 1.1573076704178809, 1.1432821204658308, 1.3390794499322134, 1.1908812733386784, 1.1957322707905236, 1.2356775502371475, 1.4860185839272613, 1.5909979169463422, 1.487838348464007, 2.033813589750779, 1.1672116139775512, 0.8583089296760609, 1.0804835132234334, 1.1325303288610313, 1.6462170166474455, 1.0259241617690775, 1.1529144853621685, 1.0165093264578273, 1.0161100004821773, 1.0851629885155019, 1.1301468255659548, 1.0511208249257085]

# %%
import matplotlib.pyplot as plt
plt.plot(x_test,y_pred,color='red')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\LJENG\AppData\Local\Temp\ipykernel_1608\1191294851.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas as pd
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df[['TV', 'Radio', 'Newspaper']]
y=df['Sales']

# %%
print(x.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %%
x.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper'], dtype='object')

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
diff=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
diff
# Out:
#      Actual  Predicted
# 58     23.8  21.735772
# 40     16.6  16.456938
# 34      9.5   7.659932
# 102    14.8  17.892027
# 184    17.6  18.677307
# 198    25.5  23.862719
# 95     16.9  16.336236
# 4      12.9  13.456492
# 29     10.5   9.177296
# 168    17.1  17.360562
# 171    14.5  14.467799
# 18     11.3   9.856976
# 11     17.4  17.260570
# 89     16.7  16.718669
# 110    13.4  15.095303
# 118    15.9  15.589237
# 159    12.9  12.451882
# 35     12.8  17.279252
# 136     9.5  11.094411
# 59     18.4  18.068899
# 51     10.7   9.334331
# 16     12.5  12.913458
# 44      8.5   8.784280
# 94     11.5  10.466707
# 31     11.9  11.403032
# 162    14.9  15.031047
# 38     10.1   9.784794
# 28     18.9  19.460286
# 193    19.6  18.229549
# 27     15.9  17.195890
# 47     23.2  21.603042
# 165    11.9  14.719014
# 194    17.3  16.292055
# 177    11.7  12.364323
# 176    20.2  19.988313
# 97     15.5  15.375564
# 174    11.5  13.966783
# 73     11.0  10.068095
# 69     22.3  20.971973
# 172     7.6   7.458778

# %%
print("Coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# Coefficient: [0.0468431  0.17854434 0.00258619]
# Intercept: 2.9079470208164295

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_squared_error(y_test,y_pred))
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 1.0402154012924718
# MSE: 1.9918855518287906
# R2 Score: 0.8927605914615384

# %%
import pandas as pd
df=pd.read_csv("FuelConsumptionCo2.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# 1              M6        Z                  11.2                  7.7
# 2             AV7        Z                   6.0                  5.8
# 3             AS6        Z                  12.7                  9.1
# 4             AS6        Z                  12.1                  8.7
# ...           ...      ...                   ...                  ...
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
o=df.drop(columns=['MAKE','MODEL','VEHICLECLASS','TRANSMISSION','FUELTYPE','MODELYEAR'])
o
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS  AGE
# 0                      8.5                        33           196   12
# 1                      9.6                        29           221   12
# 2                      5.9                        48           136   12
# 3                     11.1                        25           255   12
# 4                     10.6                        27           244   12
# ...                    ...                       ...           ...  ...
# 1062                  11.8                        24           271   12
# 1063                  11.5                        25           264   12
# 1064                  11.8                        24           271   12
# 1065                  11.3                        25           260   12
# 1066                  12.8                        22           294   12
#
# [1067 rows x 8 columns]

# %%
df['AGE']=2026-df['MODELYEAR']
df['AGE']
# Out:
# 0       12
# 1       12
# 2       12
# 3       12
# 4       12
#         ..
# 1062    12
# 1063    12
# 1064    12
# 1065    12
# 1066    12
# Name: AGE, Length: 1067, dtype: int64

# %%
o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1067 non-null   float64
#  1   CYLINDERS                 1067 non-null   int64
#  2   FUELCONSUMPTION_CITY      1067 non-null   float64
#  3   FUELCONSUMPTION_HWY       1067 non-null   float64
#  4   FUELCONSUMPTION_COMB      1067 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  6   CO2EMISSIONS              1067 non-null   int64
#  7   AGE                       1067 non-null   int64
# dtypes: float64(4), int64(4)
# memory usage: 66.8 KB

# %%
o.columns
# Out:
# Index(['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS', 'AGE'],
#       dtype='object')

# %%
x=df[['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_COMB']]
y=df['CO2EMISSIONS']

# %%
print(x.shape)
print(y.shape)
# Out:
# (1067, 3)
# (1067,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (960, 3)
# (107, 3)
# (960,)
# (107,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
diff1=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
diff1
# Out:
#      Actual   Predicted
# 133     274  256.432708
# 340     200  193.352536
# 948     196  198.683909
# 704     161  184.686780
# 661     320  308.315178
# ..      ...         ...
# 404     165  215.480464
# 762     278  264.297040
# 428     218  203.216890
# 104     292  294.718256
# 602     184  191.618980
#
# [107 rows x 2 columns]

# %%
print("Coeffiecient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# Coeffiecient: [11.99609526  7.01293926  9.33141922]
# Intercept: 67.32289813625746

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_squared_error(y_test,y_pred))
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 15.842620018066533
# MSE: 468.5277449013732
# R2 Score: 0.888899591328306

# %%
import pandas as pd
df=pd.read_csv("polylinearregression.csv")
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sno          6 non-null      int64
#  1   Temperature  6 non-null      int64
#  2   Pressure     6 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 276.0 bytes

# %%
df.columns
# Out:
# Index(['sno', 'Temperature', 'Pressure'], dtype='object')

# %%
x=df[['Temperature']]
y=df['Pressure']

# %%
print(x.shape)
print(y.shape)
# Out:
# (6, 1)
# (6,)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.00e+00 0.00e+00 0.00e+00 0.00e+00]
#  [1.00e+00 2.00e+01 4.00e+02 8.00e+03]
#  [1.00e+00 4.00e+01 1.60e+03 6.40e+04]
#  [1.00e+00 6.00e+01 3.60e+03 2.16e+05]
#  [1.00e+00 8.00e+01 6.40e+03 5.12e+05]
#  [1.00e+00 1.00e+02 1.00e+04 1.00e+06]]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_poly,y)
y_pred=lr.predict(x_poly)

# %%
from sklearn.metrics import r2_score
print("R2 Score:",metrics.r2_score(y,y_pred))
# Out:
# R2 Score: 0.9966691251761722

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
plt.scatter(x,y,color='blue')
plt.plot(x,y_pred,color='red')
plt.show()

# %%
import pandas as pd
df=pd.read_csv("car_data.csv")
df
# Out:
#    Horsepower  Weight  MPG
# 0         130    3504   18
# 1         165    3693   15
# 2         150    3436   18
# 3         140    3433   16
# 4         198    4341   14
# 5         220    4354   12
# 6          95    2372   25
# 7          88    2130   27
# 8          98    2228   24

# %%
df.columns
# Out:
# Index(['Horsepower', 'Weight', 'MPG'], dtype='object')

# %%
x=df[['Horsepower', 'Weight']]
y=df[ 'MPG']

# %%
print(x.shape)
print(y.shape)
# Out:
# (9, 2)
# (9,)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.0000000e+00 1.3000000e+02 3.5040000e+03 1.6900000e+04 4.5552000e+05
#   1.2278016e+07]
#  [1.0000000e+00 1.6500000e+02 3.6930000e+03 2.7225000e+04 6.0934500e+05
#   1.3638249e+07]
#  [1.0000000e+00 1.5000000e+02 3.4360000e+03 2.2500000e+04 5.1540000e+05
#   1.1806096e+07]
#  [1.0000000e+00 1.4000000e+02 3.4330000e+03 1.9600000e+04 4.8062000e+05
#   1.1785489e+07]
#  [1.0000000e+00 1.9800000e+02 4.3410000e+03 3.9204000e+04 8.5951800e+05
#   1.8844281e+07]
#  [1.0000000e+00 2.2000000e+02 4.3540000e+03 4.8400000e+04 9.5788000e+05
#   1.8957316e+07]
#  [1.0000000e+00 9.5000000e+01 2.3720000e+03 9.0250000e+03 2.2534000e+05
#   5.6263840e+06]
#  [1.0000000e+00 8.8000000e+01 2.1300000e+03 7.7440000e+03 1.8744000e+05
#   4.5369000e+06]
#  [1.0000000e+00 9.8000000e+01 2.2280000e+03 9.6040000e+03 2.1834400e+05
#   4.9639840e+06]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_poly,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7, 6)
# (2, 6)
# (7,)
# (2,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
diff1=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
diff1
# Out:
#    Actual  Predicted
# 8      24  25.537162
# 2      18  15.756076

# %%
from sklearn.metrics import r2_score
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 print("R2 Score:",metrics.r2_score(y_test,y_pred))
#
# NameError: name 'metrics' is not defined

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd

x=[1,2,3,4,5]
y=[1,47,96,516,425]
x=pd.DataFrame(x)
y=pd.Series(y)
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
model=LinearRegression()
model.fit(x_poly,y)
y_pred=model.predict(x_poly)

print("R2 Score:",r2_score(y,y_pred))
# Out:
# R2 Score: 0.7812950230571898
